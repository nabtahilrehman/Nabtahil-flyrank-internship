# %% [markdown]
# <a href="https://colab.research.google.com/github/nabtahilrehman/Nabtahil-flyrank-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nabtahilrehman/Nabtahil-flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
I selected Lane 2: Search Opportunity Prioritization because the goal is to identify pages that appear to have untapped search potential.

Pages with meaningful impressions but relatively low click performance may represent opportunities for SEO improvements. Rather than reviewing thousands of pages manually, this lane helps prioritize content that may benefit most from additional optimization.

The outcome is intended to support decision-making and prioritization rather than guarantee traffic gains.
"""
# Out:
# '\nI selected Lane 2: Search Opportunity Prioritization because the goal is to identify pages that appear to have untapped search potential.\n\nPages with meaningful impressions but relatively low click performance may represent opportunities for SEO improvements. Rather than reviewing thousands of pages manually, this lane helps prioritize content that may benefit most from additional optimization.\n\nThe outcome is intended to support decision-making and prioritization rather than guarantee traffic gains.\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"""
Decision:
Which pages should be prioritized first for SEO improvement efforts?

Who acts on it?
An SEO Analyst or Content Manager.

Action:
Review and optimize the highest-priority pages before spending resources on lower-impact pages.

Cost of a wrong recommendation:
Resources may be spent on pages with little opportunity, while higher-value pages may be overlooked.
"""
# Out:
# '\nDecision:\nWhich pages should be prioritized first for SEO improvement efforts?\n\nWho acts on it?\nAn SEO Analyst or Content Manager.\n\nAction:\nReview and optimize the highest-priority pages before spending resources on lower-impact pages.\n\nCost of a wrong recommendation:\nResources may be spent on pages with little opportunity, while higher-value pages may be overlooked.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")


print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

print("Average impressions:", round(df["impressions_90d"].mean(), 2))
print("Average clicks:", round(df["clicks_90d"].mean(), 2))
print("Pages with zero impressions:", (df["impressions_90d"] == 0).sum())
print("Maximum impressions:", df["impressions_90d"].max())
# Out:
# Number of rows: 30000
# Number of columns: 44
# Average impressions: 5200.37
# Average clicks: 16.1
# Pages with zero impressions: 0
# Maximum impressions: 517715

# %%
## 3. Quick look at the data (2–3 real numbers)
"""
The large variation in impressions suggests that not all pages perform equally.

This variation creates an opportunity to investigate which pages may deserve prioritization and which are already performing well.
"""
# Out:
# '\nThe large variation in impressions suggests that not all pages perform equally.\n\nThis variation creates an opportunity to investigate which pages may deserve prioritization and which are already performing well.\n'

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""
This project is intended as a decision-support system that identifies patterns in observed search performance data.

The results may help prioritize SEO opportunities, but they do not establish causation and cannot predict Google's ranking algorithm.

Any recommendations should be interpreted as observed and directional evidence rather than certainty.
"""
# Out:
# "\nThis project is intended as a decision-support system that identifies patterns in observed search performance data.\n\nThe results may help prioritize SEO opportunities, but they do not establish causation and cannot predict Google's ranking algorithm.\n\nAny recommendations should be interpreted as observed and directional evidence rather than certainty.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
