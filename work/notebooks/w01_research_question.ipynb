# %% [markdown]
# <a href="https://colab.research.google.com/github/nabtahilrehman/Nabtahil-flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nabtahilrehman/Nabtahil-flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
I selected Lane 2: Search Opportunity Prioritization because it is dedicated to finding pages that have high search demand but low visibility.
This may be useful in prioritizing work for improving the web pages. Instead of optimizing all the pages,
SEO teams can concentrate on the pages which have the highest potential to generate more traffic.
This lane is useful because it gives data, which helps with making decisions instead of guesses.
"""
# Out:
# '\nI selected Lane 2: Search Opportunity Prioritization because it is dedicated to finding pages that have high search demand but low visibility.\nThis may be useful in prioritizing work for improving the web pages. Instead of optimizing all the pages,\nSEO teams can concentrate on the pages which have the highest potential to generate more traffic.\nThis lane is useful because it gives data, which helps with making decisions instead of guesses.\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
"""
Decision: Identify pages to focus on for SEO.

Who acts on it?
An SEO Analyst or Content Manager.

Action:
Make the pages with high search volume, but low visibility, better, then focus on lower impact pages.

Wrong recommendation cost:
Incorrect pages can lead to a loss of time and money, and opportunities may be lost.

The rationale for data/ML:
Machine learning is capable of learning patterns from the data that can be used to rank pages more effectively than human effort.
"""
# Out:
# '\nDecision: Identify pages to focus on for SEO.\n\nWho acts on it?\nAn SEO Analyst or Content Manager.\n\nAction:\nMake the pages with high search volume, but low visibility, better, then focus on lower impact pages.\n\nWrong recommendation cost:\nIncorrect pages can lead to a loss of time and money, and opportunities may be lost.\n\nThe rationale for data/ML:\nMachine learning is capable of learning patterns from the data that can be used to rank pages more effectively than human effort.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")


print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

print("Average impressions:", round(df["impressions_90d"].mean(), 2))
print("Average clicks:", round(df["clicks_90d"].mean(), 2))
print("Pages with zero impressions:", (df["impressions_90d"] == 0).sum())
# Out:
# Number of rows: 30000
# Number of columns: 44
# Average impressions: 5200.37
# Average clicks: 16.1
# Pages with zero impressions: 0

# %%
## 3. Quick look at the data (2–3 real numbers)
"""
The starter data set has **30,000 pages** and **44 features** to investigate patterns of search performance.
The average impression is 5200.37 and the average click is 16.10.
The data indicates some variation in the performance of the pages
which could be considered a good sign and can be used to explore opportunities for better SEO in these pages.
"""
# Out:
# '\nThe starter data set has **30,000 pages** and **44 features** to investigate patterns of search performance.\nThe average impression is 5200.37 and the average click is 16.10.\nThe data indicates some variation in the performance of the pages\nwhich could be considered a good sign and can be used to explore opportunities for better SEO in these pages.\n'

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""
This project is meant to be a decision support system, which means it will find pattern in the data available.
The results can be helpful to prioritize potential SEO opportunities,
but it does not necessarily mean that they establish a cause-and-effect relationship or that it can predict Google's ranking algorithm.
Recommendations should be considered as directionally based evidence from the observed set of data.
"""
# Out:
# "\nThis project is meant to be a decision support system, which means it will find pattern in the data available.\nThe results can be helpful to prioritize potential SEO opportunities,\nbut it does not necessarily mean that they establish a cause-and-effect relationship or that it can predict Google's ranking algorithm.\nRecommendations should be considered as directionally based evidence from the observed set of data.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
